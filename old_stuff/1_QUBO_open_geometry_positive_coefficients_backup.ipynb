# %% [markdown]
# # 1. QUBO on an open geometry with positive coefficients
#
# Here we consider the following QUBO problem
# $
# H = J_1 \sum_ix_i + J_2 \sum_{ij}x_ix_j
# $
# where $J_2>0$ and $J_1$ could be tuned to be either positive or negative. The binary variables $x_i$ correspond to the atoms in the graphene with open geometry.
#
# The first step is to specify the geometry as a list of neighbors (here we use 2x2 cells with 8 atoms as an example)

# %%
neighbors = [
    (0, 1), (1, 2), (1, 3), (2, 4), (3, 5), (4, 6), (5, 6), (6, 7)
]

# %% [markdown]
# Next, we define the QUBO problem

# %%
import functools as ft
import numpy as np

def tensor(N, indices):
    """Return the tensor product of a set of binary variables
    
    Example 1: 
        tensor(2, [0, 1]) = array([0, 0, 0, 1]) represents x0x1 with N=2 variables
    
    Example 2: 
        tensor(3, [0, 1]) = array([0, 0, 0, 0, 0, 0, 1, 1]) represents x0x1 with N=3 variables    
        
    Example 3: 
        tensor(3, [0, 2]) = array([0, 0, 0, 0, 0, 1, 0, 1]) represents x0x2 with N=3 variables    
        
    Example 4: 
        tensor(3, [1]) = array([0, 0, 1, 1, 0, 0, 1, 1]) represents x1 with N=3 variables    
        
    Example 5: 
        tensor(3, [0,1,2]) = array([0, 0, 0, 0, 0, 0, 0, 1]) represents x0x1x2 with N=3 variables    
        
    """
    
    list_binary_variables = [(1, 1) for _ in range(N)]
    for ind in indices:
        list_binary_variables[ind] = (0, 1)
        
    return ft.reduce(np.kron, list_binary_variables)

def QUBO(neighbors, J1=0.080403, J2=0.019894):
    J1 = float(J1)
    J2 = float(J2)
    num_atoms = max(list(sum(neighbors, ()))) + 1
    
    H = 0
    # Add the linear tearm
    for i in range(num_atoms):
        H += J1 * tensor(num_atoms, [i])    
        
    # Add the quadratic term
    for (i,j) in neighbors:
        H += J2 * tensor(num_atoms, [i, j])
    
    min_val = min(H)
    min_val_indices = [i for i in range(len(H)) if H[i]==min_val]
    configs = [f'{index:0{num_atoms}b}' for index in min_val_indices]
    
    return H, (min_val, min_val_indices), configs

# %% [markdown]
# We test several values for J1, and it seems like `QUBO` all gives the correct results.

# %%
H, (min_val, min_val_indices), configs = QUBO(neighbors, J1=-0.05)
min_val, configs
# Out:
# (-0.26021199999999994, ['10111101'])

# %% [markdown]
# Now we embed the QUBO to the Rydberg Hamiltonian shown in this [example notebook](https://github.com/amazon-braket/amazon-braket-examples/blob/main/examples/analog_hamiltonian_simulation/00_Introduction_of_Analog_Hamiltonian_Simulation_with_Rydberg_Atoms.ipynb). Particularly, we are interested in mapping the QUBO to the following Rydberg Hamiltonian with nonzero global detuning
#
# \begin{align}
# H_\text{ryd} = -\Delta_\text{global}\sum_kn_k + \sum_{j=1}^{N-1}\sum_{k=1}^{N}\frac{C_6}{R_{jk}^6}n_jn_k
# \end{align}
#
# When $x_j=1$, the corresponding atom will be excited to the Rydberg state, i.e., $n_j=1$. Similarly, $x_j=0$ corresponds to $n_j=0$.
#
# Let us now determine the atomic distance $R_{jk}$. Suppose we use the maximum allowed detuning $\Delta_\text{global}^\text{max}$, then we have
# \begin{align}
# \frac{J_1}{J_2} = \frac{\Delta_\text{global}^\text{max}}{C_6/R^6}
# \end{align}
# which give
# \begin{align}
# R = \left(\frac{C_6}{\Delta_\text{global}^\text{max}}\frac{J_1}{J_2}\right)^{1/6}
# \end{align}
# Typically, we have $\Delta_\text{global}^\text{max}=1.25\times10^8$ rad/s and $C_6 = 5.42\times10^{-24} \text{rad m}^6/s$.
#
# We note that we only consider the nearest neighbor (NN) interaction here, because the next-nearest neighbor (NNN) interaction is negligible. To see that, we note the distance between NNN atoms are $\sqrt{3}$ times the distance between the NN atoms, and hence the interaction between the NNN atoms is $1/27$ times the interaction between the NN atoms.

# %%
from braket.ahs.atom_arrangement import AtomArrangement
from braket.timings.time_series import TimeSeries
from braket.ahs.driving_field import DrivingField
from braket.ahs.analog_hamiltonian_simulation import AnalogHamiltonianSimulation

from braket.analog_hamiltonian_simulator.rydberg.constants import (
    RYDBERG_INTERACTION_COEF,
    SPACE_UNIT,
    TIME_UNIT,
)

from braket.analog_hamiltonian_simulator.rydberg.rydberg_simulator_helpers import (
    get_blockade_configurations,
    _get_sparse_ops,
    _get_coefs
)

from braket.analog_hamiltonian_simulator.rydberg.rydberg_simulator_unit_converter import (
    convert_unit,
)

import warnings


def QUBO_ryd(coords, 
             Delta_max=1.25e8, 
             J1=0.080403, 
             J2=0.019894,
             C6 = 5.42e-24,
             threshold_factor = 1/18
            ):
    
    """
    The coords are scaled such that the distance of NN atoms are 1
    The threshold_factor is defined as following
    
        if J2 * threshold_factor > J1, then we will need define R in a different way
    """
    
    J1 = float(J1)
    J2 = float(J2)
    assert J2 > 0 
    
    if J1 == 0:
        Delta_max = 0
#         R = 8e-6
    elif J1 < 0:
        Delta_max = abs(Delta_max)
    else:
        Delta_max = -abs(Delta_max)
        
    if J2 * threshold_factor < abs(J1):
        a = 1
        R = a * (C6/Delta_max * -J1/J2)**(1/6)
    else:
        warnings.warn("J1 is too small")
        R1 = (C6 / 27 / abs(Delta_max))**(1/6)
        R2 = (C6 / abs(Delta_max))**(1/6)        
        R = (R1+R2)/2
        
#     a = 1
#     R = a * (C6/Delta_max * -J1/J2)**(1/6)

#     a = 2.5
#     R = a * (C6/Delta_max * -J1/J2)**(1/6)


#     print(f"R={R}, V={C6/(R**6)}, Delta_max = {Delta_max}")
#     print(f"R={R}, R1={R1}, R2={R2}, V={C6/(R**6)}, Delta_max = {Delta_max}")
    
    
    
    num_atoms = len(coords)
    
    # We will define the Hamiltonian via a ficticious AHS program
    
    # Define the register 
    register = AtomArrangement()

    for coord in coords:
        register.add(np.array(coord) * R)
        
    # Define a const driving field with zero Rabi frequency, and 
    # max allowed detuning
    t_max = 4e-6
    Omega = TimeSeries().put(0.0, 0.0).put(t_max, 0.0)
    Delta = TimeSeries().put(0.0, Delta_max).put(t_max, Delta_max)
    phi = TimeSeries().put(0.0, 0.0).put(t_max, 0.0)
    
    drive = DrivingField(
        amplitude=Omega,
        phase=phi,
        detuning=Delta
    )
    
    program = AnalogHamiltonianSimulation(
        hamiltonian=drive,
        register=register
    )
    
    
    # Now extract the Hamiltonian as a matrix from the program
    
    program = convert_unit(program.to_ir())
        
    configurations = get_blockade_configurations(program.setup.ahs_register, 0.0)

    
    rydberg_interaction_coef = RYDBERG_INTERACTION_COEF / ((SPACE_UNIT**6) / TIME_UNIT)
        
    rabi_ops, detuning_ops, interaction_op, local_detuning_ops = _get_sparse_ops(
        program, configurations, rydberg_interaction_coef
    )
        
    t_max_converted = program.hamiltonian.drivingFields[0].amplitude.time_series.times[-1]
    rabi_coefs, detuning_coefs, local_detuing_coefs = _get_coefs(program, [0, t_max_converted])
    
#     print(f"interaction_op={interaction_op}")
#     print(f"detuning_ops[0]={detuning_ops[0]}")
#     print(f"detuning_coefs[0][-1]={detuning_coefs[0][-1]}")
    
    H = interaction_op - detuning_ops[0] * detuning_coefs[0][-1]
    
    # H is diagonal
    diagH = H.diagonal()
        
    min_val = min(diagH)
    min_val_indices = [i for i in range(len(diagH)) if diagH[i]==min_val]
    configs = [f'{index:0{num_atoms}b}' for index in min_val_indices]
    
    return diagH, (min_val, min_val_indices), configs

# %% [markdown]
# ### For 2x2 cells with 8 atoms

# %%
coords = [[0, 0], 
          [0, -1],
          [-np.sqrt(3)/2, -3/2],
          [np.sqrt(3)/2, -3/2],
          [-np.sqrt(3)/2, -5/2],
          [np.sqrt(3)/2, -5/2],
          [0, -3],
          [0, -4],
         ]

neighbors = [
    (0, 1), (1, 2), (1, 3), (2, 4), (3, 5), (4, 6), (5, 6), (6, 7)
]


# J1 = -0.00001 # a = 3
# J1 = -0.0001 # a = 2
# J1 = -0.001 # a = 1.5
J1 = -0.01 # ? 
# J1 = -0.1 # a = 1

# J1 = -0.0011

diagH, (min_val, min_val_indices), configs = QUBO_ryd(coords, J1=J1)
print(min_val, configs)

H, (min_val, min_val_indices), configs = QUBO(neighbors, J1=J1)
print(min_val, configs)
# Out:
# (-476.18337108470786+0j) ['10011001', '10100101']
# -0.04 ['01001101', '10001101', '10011001', '10100101', '10110001', '10110010']

# %%
J1range = [-1/i for i in np.linspace(10, 1e2, 100)]

for J1 in J1range:
    
    _, _, configs_1 = QUBO_ryd(coords, J1=J1)

    _, _, configs_2 = QUBO(neighbors, J1=J1)

    configs_3 = [config for config in configs_1 if config in configs_2]
    print(f"len(configs_1), len(configs_2), len(configs_3) = {len(configs_1)}, {len(configs_2)}, {len(configs_3)}, J1={J1}")
# Out:
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.1
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.09166666666666667
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.08461538461538462
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.07857142857142857
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.07333333333333333
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.06875
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.06470588235294118
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 0, J1=-0.06111111111111111
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.05789473684210526
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.05500000000000001
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.05238095238095238
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.05
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.04782608695652175
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.04583333333333333
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.044000000000000004
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.04230769230769231
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.04074074074074074
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.039285714285714285
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.03793103448275862
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.03666666666666667
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.035483870967741936
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.034375
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.03333333333333333
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.032352941176470584
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.03142857142857143
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.030555555555555555
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.029729729729729728
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.02894736842105263
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.028205128205128206
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.027500000000000004
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.026829268292682926
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.02619047619047619
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.02558139534883721
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.025
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.024444444444444446
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.023913043478260874
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.023404255319148935
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.02291666666666667
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.022448979591836733
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 1, J1=-0.022000000000000002
# len(configs_1), len(configs_2), len(configs_3) = 2, 1, 0, J1=-0.021568627450980395
# len(configs_1), len(configs_2), len(configs_3) = 2, 1, 0, J1=-0.021153846153846155
# len(configs_1), len(configs_2), len(configs_3) = 2, 1, 0, J1=-0.020754716981132078
# len(configs_1), len(configs_2), len(configs_3) = 2, 1, 0, J1=-0.020370370370370372
# len(configs_1), len(configs_2), len(configs_3) = 2, 1, 0, J1=-0.02
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.019642857142857142
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.01929824561403509
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.01896551724137931
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.01864406779661017
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.018333333333333333
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.018032786885245903
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.017741935483870968
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.01746031746031746
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.0171875
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.016923076923076926
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.016666666666666666
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.016417910447761194
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.016176470588235296
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.015942028985507246
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.015714285714285715
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.015492957746478873
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.015277777777777777
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.015068493150684932
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.014864864864864864
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.014666666666666666
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.014473684210526316
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.014285714285714285
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.014102564102564103
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.013924050632911394
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.013750000000000002
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.013580246913580249
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.013414634146341463
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.01325301204819277
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.013095238095238096
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.012941176470588237
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.012790697674418606
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.01264367816091954
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.0125
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.012359550561797753
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.012222222222222223
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.012087912087912088
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.011956521739130433
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.011827956989247311
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.011702127659574468
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.011578947368421053
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.011458333333333334
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.011340206185567012
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.011224489795918367
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.011111111111111112
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.011000000000000001
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.010891089108910892
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.010784313725490198
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.010679611650485437
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.010576923076923078
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.010476190476190476
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.010377358490566039
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.010280373831775701
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.010185185185185186
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.010091743119266056
# len(configs_1), len(configs_2), len(configs_3) = 2, 6, 2, J1=-0.01

# %% [markdown]
# ### For 3x3 cells with 18 atoms

# %%
coords = [[0, 0], 
          [0, -1],
          [-np.sqrt(3)/2, -3/2],
          [np.sqrt(3)/2, -3/2],
          [-np.sqrt(3)/2, -5/2],
          [np.sqrt(3)/2, -5/2],
          [-np.sqrt(3), -3],
          [0, -3],
          [np.sqrt(3), -3],
          [-np.sqrt(3), -4],
          [0, -4],
          [np.sqrt(3), -4],
          [-np.sqrt(3)/2, -9/2],
          [np.sqrt(3)/2, -9/2],
          [-np.sqrt(3)/2, -10/2],
          [np.sqrt(3)/2, -10/2],                    
          [0, -6],
          [0, -7],
         ]

neighbors = [
    (0, 1), 
    (1, 2), (1, 3), 
    (2, 4), (3, 5), 
    (4, 6), (4, 7), (5, 7), (5, 8),
    (6, 9), (7, 10), (8, 11),
    (9, 12), (10, 12), (10, 13), (11, 13),
    (12, 14), (13, 15),
    (14, 16), (15, 16),
    (16, 17)
]


# J1 = -0.00001 # a = 3
# J1 = -0.0001 # a = 2
# J1 = -0.001 # a = 1.5
# J1 = -0.01 # ? 
J1 = -0.1 # a = 1

# J1 = -0.0011

H, (min_val, min_val_indices), configs = QUBO(neighbors, J1=J1)
print(min_val, configs)


diagH, (min_val, min_val_indices), configs = QUBO_ryd(coords, J1=J1)
print(min_val, configs)
# Out:
# -1.3822259999999988 ['111111111111111111']
# (-1625.0178575909356+0j) ['111111111111001111']

# %%
J1range = [-1/i for i in np.linspace(10, 1e3, 100)]

for J1 in J1range:
    
    _, _, configs_1 = QUBO_ryd(coords, J1=J1)

    _, _, configs_2 = QUBO(neighbors, J1=J1)

    configs_3 = [config for config in configs_1 if config in configs_2]
    print(f"len(configs_1), len(configs_2), len(configs_3) = {len(configs_1)}, {len(configs_2)}, {len(configs_3)}, J1={J1}")
# Out:
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 0, J1=-0.1
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 0, J1=-0.05
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 0, J1=-0.03333333333333333
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 0, J1=-0.025
# len(configs_1), len(configs_2), len(configs_3) = 1, 1, 0, J1=-0.02
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.016666666666666666
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.014285714285714285
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0125
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.011111111111111112
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.01
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.00909090909090909
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.008333333333333333
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.007692307692307693
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.007142857142857143
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.006666666666666667
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.00625
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0058823529411764705
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.005555555555555556
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.005263157894736842
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.005
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.004761904761904762
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.004545454545454545
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.004347826086956522
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.004166666666666667
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.004
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0038461538461538464
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.003703703703703704
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0035714285714285713
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0034482758620689655
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.0033333333333333335
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.0032258064516129032
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.003125
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.0030303030303030303
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.0029411764705882353
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.002857142857142857
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.002777777777777778
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.002702702702702703
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.002631578947368421
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.002564102564102564
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.0025
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.0024390243902439024
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.002380952380952381
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.002325581395348837
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.0022727272727272726
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0022222222222222222
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.002173913043478261
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.002127659574468085
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0020833333333333333
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0020408163265306124
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.002
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.00196078431372549
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0019230769230769232
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0018867924528301887
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 0, J1=-0.001851851851851852
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0018181818181818182
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0017857142857142857
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0017543859649122807
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0017241379310344827
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.001694915254237288
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0016666666666666668
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.001639344262295082
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0016129032258064516
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0015873015873015873
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0015625
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0015384615384615385
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0015151515151515152
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0014925373134328358
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0014705882352941176
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0014492753623188406
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0014285714285714286
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0014084507042253522
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.001388888888888889
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0013698630136986301
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0013513513513513514
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0013333333333333333
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0013157894736842105
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0012987012987012987
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.001282051282051282
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0012658227848101266
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.00125
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0012345679012345679
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0012195121951219512
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0012048192771084338
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0011904761904761906
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.001176470588235294
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0011627906976744186
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0011494252873563218
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0011363636363636363
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0011235955056179776
# len(configs_1), len(configs_2), len(configs_3) = 2, 20, 0, J1=-0.0011111111111111111
# /var/folders/17/wqjdf0nn4dj11p1h8yrx44100000gr/T/ipykernel_82855/3077496220.py:56: UserWarning: J1 is too small
#   warnings.warn("J1 is too small")
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.001098901098901099
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0010869565217391304
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.001075268817204301
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0010638297872340426
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0010526315789473684
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0010416666666666667
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0010309278350515464
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.0010204081632653062
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.00101010101010101
# len(configs_1), len(configs_2), len(configs_3) = 1, 20, 1, J1=-0.001

# %%
# diagH

# %%
# def QUBO_program(): # adiabatic program
#     pass
